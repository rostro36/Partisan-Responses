# %% [markdown]
# <a href="https://colab.research.google.com/github/rostro36/Partisan-Responses/blob/master/QA%2Bgeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
#https://huggingface.co/transformers/usage.html#extractive-question-answering
from transformers import pipeline
# Out:
# ...
#      |████████████████████████████████| 675kB 3.4MB/s
# ...
#      |████████████████████████████████| 3.8MB 14.7MB/s
# ...
#      |████████████████████████████████| 890kB 30.7MB/s
# ...
#      |████████████████████████████████| 1.1MB 35.2MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=84ec186b3c267f36d053cce6d256617cd7b4107b015687485a12559212f99350
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
nlp = pipeline("question-answering")

context = r"""
Extractive Question Answering is the task of extracting an answer from a text given a question. An example of a
question answering dataset is the SQuAD dataset, which is entirely based on that task. If you would like to fine-tune
a model on a SQuAD task, you may leverage the `run_squad.py`.
"""

print(nlp(question="What is extractive question answering?", context=context))
print(nlp(question="What is a good example of a question answering dataset?", context=context))
print()
# Out:
# ...
# {'score': 0.6222326537500251, 'start': 34, 'end': 96, 'answer': 'the task of extracting an answer from a text given a question.'}
# {'score': 0.5115300495513679, 'start': 147, 'end': 161, 'answer': 'SQuAD dataset,'}

# %%
print(nlp(question="What is extractive question answering?", context=context)['answer'])
# Out:
# the task of extracting an answer from a text given a question.

# %%
text_generator = pipeline("text-generation")
print(text_generator("As far as I am concerned, I will", max_length=50))
# Out:
# ...
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# [{'generated_text': 'As far as I am concerned, I will be running for the U.S. Senate even if I lose this election."\n\n(CNNPolitics.com)\n\nHe added: "There\'s always a possibility but I can\'t tell you'}]

# %%
answer=nlp(question="What is extractive question answering?", context=context)['answer']
print(text_generator(answer, max_length=50))
# Out:
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# [{'generated_text': "the task of extracting an answer from a text given a question. One form of question processing can be described as a 'deep' search. An exhaustive, finite set of search operations can be generated if there is sufficient data as well as a sufficient sample"}]
